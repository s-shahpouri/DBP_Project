# %%
import os
import copy
import numpy as np
import os
import json
import glob
import random

# %%
# file_path = '/home/shahpouriz/Data/DBP_CTs/DBP_OP042_coordination_data.json'

# %%
import glob
import os
import json

class DirectoryProcessor:
    def __init__(self, directory_path):
        self.directory_path = directory_path

    def process_files(self):
        # Search for json files matching the pattern
        file_pattern = os.path.join(self.directory_path, '*H_coordination_data.json')
        json_files = glob.glob(file_pattern)

        results = []
        for file_path in json_files:
            with open(file_path, 'r') as file:
                data = json.load(file)

            # Initialize a dictionary to store the extracted data for this file
            file_results = {
                'id': data.get('id'),
                'examination_details': []
            }

            # Iterate through each examination detail
            for examination in data.get('examination_details', []):
                print(examination)
                # Filter for 'A1PHH' plans
            for iteration_key, iteration_value in examination.get('plans', {}).items():
                print(iteration_key)  # This will print keys like 'iteration1'
                print(iteration_value) 
                    # for plan in iteration.get('plans', []):
                    #     print(plan)
                        
                    # # if plan.get('plan_name') == 'A1PHH' and plan.get('planning_exam_name') == 'pCTp0':
                    #     # Extract and add the relevant plan details
                    #     file_results['examination_details'].append({
                    #         'plan_name': plan.get('plan_name'),
                    #         'iteration': iteration,
                    #         'planning_exam_name': plan.get('planning_exam_name'),
                    #         'repeatedCT_name': plan.get('repeatedCT_name'),
                    #         'final_translation_coordinate': plan.get('final_translation_coordinate'),
                    #         'planningCT_filename': plan.get('planningCT_filename'),
                    #         'repeatedCT_filename': plan.get('repeatedCT_filename')
                    #     })
                        
            

            # Add the file's results to the overall results list
            results.append(file_results)

        return results

# Usage
directory_path = '/data/shahpouriz/TEST'
processor = DirectoryProcessor(directory_path)
all_results = processor.process_files()

# # Optionally, print the results to verify
# for result in all_results:
#     print(result)
# all_results
# Out:
# {'exam_name': 'rCTp3', 'plans': {'iteration1': {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp3', 'transformation_matrix': [0.9999779584857218, -0.0022313662215612093, 0.00625328293884881, 16.21805685184188, 0.00239968184506036, 0.9996314883010093, -0.02703939947838101, -132.37931310324763, -0.006190643728281387, 0.02705380937861172, 0.9996148094782986, -4.3804728850925665, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': 14.800062566201708, 'y': -14.72901457405614, 'z': -6.876011881356697}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\rCTp3'}, 'iteration2': {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp3', 'transformation_matrix': [0.9999779584857218, -0.0022313662215612093, 0.00625328293884881, -10.81310017936763, 0.00239968184506036, 0.9996314883010093, -0.02703939947838101, -121.63443440736486, -0.006190643728281387, 0.02705380937861172, 0.9996148094782986, -10.863957155754074, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -12.231094465007802, 'y': -3.984135878173377, 'z': -13.359496152018204}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\rCTp3'}, 'iteration3': {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp3', 'transformation_matrix': [0.9999779584857218, -0.0022313662215612093, 0.00625328293884881, 13.724621910773687, 0.00239968184506036, 0.9996314883010093, -0.02703939947838101, -127.44722409157539, -0.006190643728281387, 0.02705380937861172, 0.9996148094782986, -5.071126062875492, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': 12.306627625133515, 'y': -9.796925562383912, 'z': -7.5666650591396225}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\rCTp3'}, 'iteration4': {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp3', 'transformation_matrix': [0.9999779584857218, -0.0022313662215612093, 0.00625328293884881, -11.02103069727988, 0.00239968184506036, 0.9996314883010093, -0.02703939947838101, -121.83338688301987, -0.006190643728281387, 0.02705380937861172, 0.9996148094782986, 2.014815020811932, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -12.43902498292005, 'y': -4.183088353828389, 'z': -0.4807239754521986}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\rCT
-0.008432046708156742, 0.009184652632175957, 0.9999222683510643, 9.315236705268454, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -11.92110297723968, 'y': -4.210407443630567, 'z': 8.44820166239243}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\rCTp29'}
# iteration7
# {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp29', 'transformation_matrix': [0.9999544150918892, 0.004557186265233158, 0.008390458365420145, -0.3339668424145765, -0.0044797685821191344, 0.9999474357231835, -0.009222660358075905, -132.7292539359743, -0.008432046708156742, 0.009184652632175957, 0.9999222683510643, 5.286288849270075, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -1.4788005838020157, 'y': -13.462831913519375, 'z': 4.419253806394051}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\rCTp29'}
# iteration8
# {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp29', 'transformation_matrix': [0.9999544150918892, 0.004557186265233158, 0.008390458365420145, -8.322047380555698, -0.0044797685821191344, 0.9999474357231835, -0.009222660358075905, -117.93301812775576, -0.008432046708156742, 0.009184652632175957, 0.9999222683510643, 0.9446027077982202, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -9.466881121943139, 'y': 1.3334038946991522, 'z': 0.0775676649221968}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\rCTp29'}
# iteration9
# {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp29', 'transformation_matrix': [0.9999544150918892, 0.004557186265233158, 0.008390458365420145, -0.07238446120031841, -0.0044797685821191344, 0.9999474357231835, -0.009222660358075905, -120.20111361976814, -0.008432046708156742, 0.009184652632175957, 0.9999222683510643, -12.261271709225097, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -1.2172182025877576, 'y': -0.9346915973132286, 'z': -13.12830675210112}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\rCTp29'}
# iteration10
# {'plan_name': 'A1PHH', 'planning_exam_name': 'pCTp0', 'repeatedCT_name': 'rCTp29', 'transformation_matrix': [0.9999544150918892, 0.004557186265233158, 0.008390458365420145, -10.677860396315427, -0.0044797685821191344, 0.9999474357231835, -0.009222660358075905, -124.04610442576832, -0.008432046708156742, 0.009184652632175957, 0.9999222683510643, 3.0708639511791, 0.0, 0.0, 0.0, 1.0], 'final_translation_coordinate': {'x': -11.822694137702868, 'y': -4.779682403313407, 'z': 2.203828908303077}, 'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\pCTp0', 'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\rCTp29'}

# %%
import glob
import os
import json

class DirectoryProcessor:
    def __init__(self, directory_path):
        self.directory_path = directory_path

    def process_files(self):
        # Search for json files matching the pattern
        file_pattern = os.path.join(self.directory_path, '*H_coordination_data.json')
        json_files = glob.glob(file_pattern)

        results = []
        for file_path in json_files:
            with open(file_path, 'r') as file:
                data = json.load(file)

            # Initialize a dictionary to store the extracted data for this file
            file_results = {
                'id': data.get('id'),
                'examination_details': []
            }

            # Iterate through each examination detail
            for examination in data.get('examination_details', []):
                # Assume each 'examination' has 'plans' which is a dictionary of iterations
                if 'plans' in examination:
                    for iteration_key, iteration_details in examination['plans'].items():
                        if iteration_details['plan_name'] == 'A1PHH' and iteration_details['planning_exam_name'] == 'pCTp0':
                            file_results['examination_details'].append({
                                'plan_name': iteration_details['plan_name'],
                                'iteration': iteration_key,
                                'planning_exam_name': iteration_details['planning_exam_name'],
                                'repeatedCT_name': iteration_details['repeatedCT_name'],
                                'final_translation_coordinate': iteration_details['final_translation_coordinate'],
                                'planningCT_filename': iteration_details['planningCT_filename'],
                                'repeatedCT_filename': iteration_details['repeatedCT_filename']
                            })
            
            # Add the file's results to the overall results list
            results.append(file_results)

        return results

# Usage
directory_path = '/data/shahpouriz/TEST'
processor = DirectoryProcessor(directory_path)
all_results = processor.process_files()

# # Optionally, print the results to verify
# for result in all_results:
#     print(result)
all_results
# Out:
# [{'id': 'DBP_OP009',
#   'examination_details': [{'plan_name': 'A1PHH',
#     'iteration': 'iteration1',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': 14.800062566201708,
#      'y': -14.72901457405614,
#      'z': -6.876011881356697},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration2',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': -12.231094465007802,
#      'y': -3.984135878173377,
#      'z': -13.359496152018204},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration3',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': 12.306627625133515,
#      'y': -9.796925562383912,
#      'z': -7.5666650591396225},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration4',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': -12.43902498292005,
#      'y': -4.183088353828389,
#      'z': -0.4807239754521986},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration5',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': -14.114711993569578,
#      'y': -13.229839979590308,
#      'z': -14.928386166405133},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration6',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x': 8.178244963883367,
#      'y': -8.356746728170343,
#      'z': 13.114018224173059},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\rCTp3'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration7',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp3',
#     'final_translation_coordinate': {'x

#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp19',
#     'final_translation_coordinate': {'x': -2.4467157343971504,
#      'y': 9.207726696035722,
#      'z': 9.80625216716326},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\rCTp19'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration1',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 13.430739330140922,
#      'y': 6.56530809330718,
#      'z': -14.955403255306445},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration2',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 5.54084149390914,
#      'y': -14.618148142004577,
#      'z': -7.916905253006586},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration3',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': -11.08630329507658,
#      'y': -5.293850611084318,
#      'z': 6.158548524416433},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration4',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': -10.505743874034156,
#      'y': 2.8406652228913387,
#      'z': -12.277635231139497},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration5',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': -8.142238534137565,
#      'y': -11.521678179514009,
#      'z': 6.949724774900133},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration6',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 8.777747666214406,
#      'y': -2.410227283514593,
#      'z': 8.499016392488286},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration7',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 0.9087913347745813,
#      'y': 7.75906518862823,
#      'z': -12.014792710798732},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration8',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 6.564324015200427,
#      'y': -7.130089711649053,
#      'z': -0.748109770577855},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration9',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': -10.19925982740548,
#      'y': 13.53066330741322,
#      'z': 11.424095896505012},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration10',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp25',
#     'final_translation_coordinate': {'x': 11.830140605555544,
#      'y': 7.277760508780309,
#      'z': -13.955281979827525},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\rCTp25'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration1',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -11.20489770294647,
#      'y': -5.25254513740663,
#      'z': 6.254048634514477},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration1\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration2',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -2.8804311486445524,
#      'y': 9.353394240428315,
#      'z': -12.76307683347764},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration2\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration3',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': 4.411466709711954,
#      'y': -9.148334388822922,
#      'z': -7.311750012285605},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration3\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration4',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': 4.986977439889214,
#      'y': -2.267861885443642,
#      'z': 11.720488020813065},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration4\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration5',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -0.6048942974343996,
#      'y': 0.6478337513644872,
#      'z': -10.673797790192925},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration5\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration6',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -11.92110297723968,
#      'y': -4.210407443630567,
#      'z': 8.44820166239243},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration6\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration7',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -1.4788005838020157,
#      'y': -13.462831913519375,
#      'z': 4.419253806394051},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration7\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration8',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -9.466881121943139,
#      'y': 1.3334038946991522,
#      'z': 0.0775676649221968},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration8\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration9',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -1.2172182025877576,
#      'y': -0.9346915973132286,
#      'z': -13.12830675210112},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration9\\rCTp29'},
#    {'plan_name': 'A1PHH',
#     'iteration': 'iteration10',
#     'planning_exam_name': 'pCTp0',
#     'repeatedCT_name': 'rCTp29',
#     'final_translation_coordinate': {'x': -11.822694137702868,
#      'y': -4.779682403313407,
#      'z': 2.203828908303077},
#     'planningCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\pCTp0',
#     'repeatedCT_filename': '//zkh/AppData/RT-Meetdata/GPTC/13 Research & Testing/DoseBasedPositioning/Project_data/Test\\DBP_OP009\\A1PHH\\iteration10\\rCTp29'}]}]

# %%
import os
import SimpleITK as sitk

class DICOMtoNRRDConverter:
    def __init__(self, directory_path, output_directory_proton, output_directory_foton):
        self.directory_path = directory_path
        self.output_directory_proton = output_directory_proton
        self.output_directory_foton = output_directory_foton
        self.directory_processor = DirectoryProcessor(directory_path)

    def convert_and_save(self):
        patient_data = self.directory_processor.process_files()
        for patient in patient_data:
            patient_id = patient['id']
            # print(patient_id)
            for plan_index, plan in enumerate(patient['examination_details']):
                # Determine the output path based on whether the plan is for proton or foton
                output_path = self.output_directory_proton if 'P' in plan['plan_name'] else self.output_directory_foton
                
                full_output_path = os.path.join(output_path, patient_id)
                if not os.path.exists(full_output_path):
                    os.makedirs(full_output_path)
                # Process files for this plan
                plan_name = plan.get('planning_exam_name')
            
                nrrd_path = self._process_dose_file(plan['planningCT_filename'], full_output_path, patient_id, plan_name, "planningCT")
                plan['planningCT_filename'] = nrrd_path or plan['planningCT_filename']
                print(plan)
                # for exam_index, exam in enumerate(plan.get('evaluation_examinations', [])):
                #     print(exam)
                exam_index = plan.get('repeatedCT_name')
                nrrd_path = self._process_dose_file(plan['repeatedCT_filename'], full_output_path, patient_id, plan_name, "repeatedCT", exam_index)
                plan['repeatedCT_filename'] = nrrd_path or plan['repeatedCT_filename']
     # Optional: Return the updated patient data for verification
        return patient_data
    

    def _process_dose_file(self, dose_dicom_dir, output_path, patient_id, plan_name, exam_type, exam_index=None):
        
        if dose_dicom_dir is None:
            # print(f"Error: The dose_dicom_dir is None for patient_id: {patient_id}, plan_name: {plan_name}")
            return None
        # Generate the full path to the DICOM directory
        full_dose_path = os.path.join(self.directory_path, dose_dicom_dir) if self.directory_path not in dose_dicom_dir else dose_dicom_dir
        
        # Check if the directory exists
        if not os.path.isdir(full_dose_path):
            # print(f"Directory not found: {full_dose_path}")
            return None
            
        # Construct NRRD filename
        nrrd_filename = f"{patient_id}_{plan_name}_{exam_type}{'' if exam_index is None else '_' + exam_index}.nrrd"
        nrrd_path = os.path.join(output_path, nrrd_filename)
        
        # Debugging print
        # print(f"Processing DICOM series from: {full_dose_path}")
        
        # Attempt to read the DICOM series and write as NRRD
        reader = sitk.ImageSeriesReader()
        dicom_names = reader.GetGDCMSeriesFileNames(full_dose_path)
        if not dicom_names:  # Check if the DICOM names list is empty
            # print(f"No DICOM files found in directory: {full_dose_path}")
            return None
        
        reader.SetFileNames(dicom_names)
        try:
            image = reader.Execute()
            sitk.WriteImage(image, nrrd_path)
            print(f"Saved NRRD file at {nrrd_path}")
            return nrrd_filename
        except RuntimeError as e:
            print(f"Error reading DICOM series from {full_dose_path}: {e}")
            return None

# %%
output_directory_proton = '/data/shahpouriz/DBP_CTs/nrrd/proton'
output_directory_foton = '/data/shahpouriz/DBP_CTs/nrrd/foton'

converter = DICOMtoNRRDConverter(directory_path, output_directory_proton, output_directory_foton)
updated_patient_data = converter.convert_and_save()

# Print the updated patient data
# for patient in updated_patient_data:
#     print(patient)

# %%
# Print the updated patient data
for patient in updated_patient_data:
    print(patient)

# %%
initial_count = len(updated_patient_data)
print(f"Initial patient count: {initial_count}")

filtered_patient_data = []

for patient in updated_patient_data:
    keep_patient = True
    if 'examination_details' not in patient:
        print(f"Skipping patient {patient.get('id', 'unknown')} due to missing examination_details.")
        continue  # Skip patients without examination_details entirely
    for plan in patient['examination_details']:  # Directly iterate through what we previously considered as 'plans'
        if plan.get('planningCT_filename') is None or plan.get('repeatedCT_filename') is None:
            print(f"Excluding plan due to missing filenames in patient {patient.get('id', 'unknown')}.")
            keep_patient = False
            break
    if keep_patient:
        filtered_patient_data.append(patient)

print(f"Filtered patient count: {len(filtered_patient_data)}")

# Optionally, print details of the filtered patients to verify the output
for patient in filtered_patient_data:
    print(patient)

# %%
# Save updated_patient_data to a JSON file
output_json_file = output_directory_proton + '/file_info.json' 
with open(output_json_file, 'w') as file:
    json.dump(filtered_patient_data, file, indent=4)
    
print(f"Updated patient data saved to {output_json_file}")
